# %% [markdown]
# # APPL Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates

# %%
df = pd.read_csv('./processed_data/AAPL_daily_data_splits_processed.csv')

# %%
df.head()
# Out:
#    time_stamp    open    high     low   close    volume   SMA_10      EMA_10  \
# 0  2024-07-26  218.70  219.49  216.01  217.96  41601345  224.955  222.440580
# 1  2024-07-25  218.93  220.85  214.62  217.49  51391199  226.213  223.436265
# 2  2024-07-24  224.00  224.80  217.13  218.54  61777576  227.221  224.757657
# 3  2024-07-23  224.36  226.94  222.68  225.01  39960260  228.665  226.139359
# 4  2024-07-22  227.01  227.78  223.09  223.96  48201835  229.032  226.390327
#
#      SMA_20      EMA_20  ...        RSI    EMA_Fast    EMA_Slow      MACD  \
# 0  224.6335  221.535174  ...  35.237197  222.671480  219.645214  3.026266
# 1  224.4405  221.911508  ...  33.528817  223.528113  219.780031  3.748082
# 2  224.2285  222.376930  ...  35.333447  224.625952  219.963234  4.662718
# 3  223.7550  222.780817  ...  49.586166  225.732489  220.077093  5.655396
# 4  222.9115  222.546166  ...  46.553918  225.863850  219.682460  6.181390
#
# ...

# %%
plt.figure(figsize=(10, 5))  # Set the figure size for readability

# Plotting the line graph
plt.plot(df['time_stamp'], df['close'], linestyle='-', color='b')  # Blue line graph without markers

# Setting the title and labels for the axes
plt.title('Split Adjusted APPL Stock Price vs Time')
plt.xlabel('Time')
plt.ylabel('Closing Price')

# Reverse the time on the x-axis
plt.gca().invert_xaxis()

# Adjusting the x-axis to only show labels every 100 days
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=730))  # Set major ticks to every 100 days

# Add grid lines for better readability
plt.grid(True)

# Automatically adjust subplot parameters to give the plot more padding
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Looks Good
